# %%
my_list=[9,3,5,6,2,3,6]
my_list
# Out:
# [9, 3, 5, 6, 2, 3, 6]

# %%
#Print the list by the index of element.
for i in range(len(my_list)):
        print(i,my_list[i])
# Out:
# 0 9
# 1 3
# 2 5
# 3 6
# 4 2
# 5 3
# 6 6

# %%
import numpy as np
my_list_1=np.array([3,3,3,3,3,3])
my_list_1+1
# Out:
# array([4, 4, 4, 4, 4, 4])

# %%
def np_list_test(my_array=np.array([3,3,3,3,3,3])):
    return my_array-10
np_list_test()
# Out:
# array([-7, -7, -7, -7, -7, -7])

# %%
import numpy as np
import matplotlib.pyplot as plt
im_1=plt.imread('ata.jpeg')
plt.imshow(im_1)
plt.show()

# %%
m,n,p=im_1.shape
im_2=np.zeros((m,n,3),dtype=int)
for m in range(im_1.shape[0]):
    for n in range(im_1.shape[1]):
        im_2[m,n,0]=im_1[m,n,0]+100
        im_2[m,n,1]=im_1[m,n,0]
        im_2[m,n,2]=im_1[m,n,0]
        # Searches pixel by pixel for assign them to im_2.
        
plt.imshow(im_2)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def red_deger(im_3,s=5):
    im_1=im_3
    m,n,p=im_1.shape
    im_2=np.zeros((m,n,3),dtype=int)
    m,n,p=im_2.shape
    for m in range(im_1.shape[0]):
        for n in range(im_1.shape[1]):
            im_2[m,n,0]=im_1[m,n,0]-s
            im_2[m,n,1]=im_1[m,n,0]
            im_2[m,n,2]=im_1[m,n,0]
            # Searches pixel by pixel for assign them to im_2.
    return im_3
im_ret=red_deger(im_1,100)
plt.imshow(im_ret)
plt.show()

# %%
# mxn to (m/2)x(n/2)
def boyutlandir(im_4):
    m,n,p=im_4.shape
    new_m=int(m/2)
    new_n=int(n/2)
    im_5=np.zeros((new_m,new_n),dtype=int)
    for m in range(new_m): 
        for n in range(new_n):
            s=(im_4[m*2,n*2,0]+im_4[m*2,n*2,1]+im_4[m*2,n*2,2])/3
            im_5[m,n]=int(s)
    return im_5

# %%
plt.imshow(im_1)
plt.show()
im_6=boyutlandir(im_1)
plt.imshow(im_6,cmap='gray')
plt.show()
# Out:
# C:\Users\ozaer\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in ubyte_scalars
#   if __name__ == '__main__':

# %%
def bozulmadan_boyutlandir(im_7):
    m,n,p=im_7.shape
    new_m=int(m/2)
    new_n=int(n/2)
    im_8=np.zeros((new_m,new_n,3),dtype=int)
    for m in range(new_m): 
        for n in range(new_n):
            im_8[m,n,0]=int(im_7[m*2,n*2,0])
            im_8[m,n,1]=int(im_7[m*2,n*2,1])
            im_8[m,n,2]=int(im_7[m*2,n*2,2])
    return im_8

plt.imshow(im_1)
plt.show()
im_8=bozulmadan_boyutlandir(im_1)
plt.imshow(im_8)
plt.show()
im_9=bozulmadan_boyutlandir(im_8)
plt.imshow(im_9)
plt.show()
im_10=bozulmadan_boyutlandir(im_9)
plt.imshow(im_10)
plt.show()
